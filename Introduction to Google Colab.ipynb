# %%
x = 7

# %%
print('Hello, world')
# Out:
# Hello, world

# %%
print(2+10)
# Out:
# 12

# %% [markdown]
# **Мы написали простейшую программу в Google Colab**
#
# *Это было интересно*

# %%
print(x+10)
# Out:
# 17
