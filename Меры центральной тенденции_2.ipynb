# %%
import numpy as np
import pandas as pd
Marvel = pd.read_csv('MarvelComicCaracters.csv', sep=';')
Marvel
# Out:
#                                       name                 align  \
# 0                Spider-Man (Peter Parker)       Добрый персонаж
# 1          Captain America (Steven Rogers)       Добрый персонаж
# 2      Wolverine (James \"Logan\" Howlett)  Нейтральный персонаж
# 3        Iron Man (Anthony \"Tony\" Stark)       Добрый персонаж
# 4                      Thor (Thor Odinson)       Добрый персонаж
# ...                                    ...                   ...
# 16371                   Ru'ach (Earth-616)         Злой персонаж
# 16372      Thane (Thanos' son) (Earth-616)       Добрый персонаж
# 16373        Tinkerer (Skrull) (Earth-616)         Злой персонаж
# 16374       TK421 (Spiderling) (Earth-616)  Нейтральный персонаж
# 16375                Yologarch (Earth-616)         Злой персонаж
#
#                  eye               hair               sex  appearances  \
# 0        Карие глаза  Каштановые волосы  Мужской персонаж       4043.0
# ...

# %%
Marvel['eye'].mode()
# Out:
# 0    Голубые глаза
# dtype: object

# %%
Marvel['eye'].iloc[500:].mode()
# Out:
# 0    Темно-карие глаза
# dtype: object

# %%
Marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16376 non-null  object
#  1   align             13564 non-null  object
#  2   eye               6609 non-null   object
#  3   hair              9989 non-null   object
#  4   sex               15522 non-null  object
#  5   appearances       15280 non-null  float64
#  6   first_appearance  15561 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 895.7+ KB

# %%
Marvel.groupby('sex')['hair'].agg(lambda x: x.mode()[0])
# Out:
# sex
# Безполый персонаж                  Без волос
# Гендерфлюидный персонаж    Каштановые волосы
# Женский персонаж               Черные волосы
# Мужской персонаж               Черные волосы
# Name: hair, dtype: object

# %%
Marvel.pivot_table(index='align', values='appearances', aggfunc='median')
# Out:
#                       appearances
# align
# Добрый персонаж               5.0
# Злой персонаж                 3.0
# Нейтральный персонаж          3.0

# %%
Marvel.groupby('align')['appearances'].median()
# Out:
# align
# Добрый персонаж         5.0
# Злой персонаж           3.0
# Нейтральный персонаж    3.0
# Name: appearances, dtype: float64

# %%
Marvel['appearances'].var(ddof=0)
# Out:
# 9287.139461894549

# %%
Marvel['first_appearance'].mode()
# Out:
# 0    1993.0
# dtype: float64

# %%
Marvel['hair'].mode()
# Out:
# 0    Черные волосы
# dtype: object

# %%
Marvel.groupby('hair')['appearances'].std(ddof=0)
# Out:
# hair
# Без волос                      81.927176
# Белые волосы                  146.246507
# Бронзовые волосы                0.000000
# Желтые волосы                  26.360745
# Зеленые волосы                 55.277098
# Золотые волосы                 80.764221
# Каштановые волосы             133.792871
# Окрашенные волосы               0.000000
# Оранжево-каштановые волосы      0.000000
# Оранжевые волосы               37.694597
# Пурпурные волосы               11.160645
# Разноцветные волосы            32.598622
# Розовые волосы                 41.352089
# Русые волосы                  122.108328
# Рыжевато-соломенные волосы    154.624994
# Светло-каштановые волосы       16.496633
# Светло-розовые волосы         142.829361
# Серебристые волосы            183.381614
# Фиолетовые волосы             105.179115
# Черные волосы                  94.132539
# Name: appearances, dtype: float64
