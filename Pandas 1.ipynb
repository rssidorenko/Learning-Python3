# %%
import pandas as pd
df = pd.DataFrame()
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['STATS'] = [7, 8, 9]
df['CALC'] = [5, 7, 10]
df
# Out:
#    STATS  CALC
# 0      7     5
# 1      8     7
# 2      9    10

# %%
df['CALC']
# Out:
# 0     5
# 1     7
# 2    10
# Name: CALC, dtype: int64

# %%
df['CALC'].name
# Out:
# 'CALC'

# %%
df['CALC'].dtype
# Out:
# dtype('int64')

# %%
df['CALC'].values
# Out:
# array([ 5,  7, 10])

# %%
type(df['CALC'].values)
# Out:
# numpy.ndarray

# %%
type(df['CALC'])
# Out:
# pandas.core.series.Series

# %%
df['AVG'] = (df['CALC'] + df['STATS']) / 2
df
# Out:
#    STATS  CALC  AVG
# 0      7     5  6.0
# 1      8     7  7.5
# 2      9    10  9.5

# %%
df[['STATS','AVG']]
# Out:
#    STATS  AVG
# 0      7  6.0
# 1      8  7.5
# 2      9  9.5

# %%
df = df[['AVG','STATS','CALC']]
df
# Out:
#    AVG  STATS  CALC
# 0  6.0      7     5
# 1  7.5      8     7
# 2  9.5      9    10

# %%
df.columns = ['AVG', 'STATS', 'CALC']
df
# Out:
#    AVG  STATS  CALC
# 0  6.0      7     5
# 1  7.5      8     7
# 2  9.5      9    10

# %%
df.iloc[2]
# Out:
# AVG       9.5
# STATS     9.0
# CALC     10.0
# Name: 2, dtype: float64

# %%
df.loc[2]
# Out:
# AVG       9.5
# STATS     9.0
# CALC     10.0
# Name: 2, dtype: float64

# %%
df.index = ['George', 'Marie', 'Alex']
df
# Out:
#         AVG  STATS  CALC
# George  6.0      7     5
# Marie   7.5      8     7
# Alex    9.5      9    10

# %%
df.loc['Alex']
# Out:
# AVG       9.5
# STATS     9.0
# CALC     10.0
# Name: Alex, dtype: float64

# %%
df.iloc[0,1]
# Out:
# 7

# %%
df.loc['Alex','CALC']
# Out:
# 10

# %%
df['STATS'][0]
# Out:
# 7

# %%
df['AVG']['Marie']
# Out:
# 7.5

# %%
d = {'a':[2,6], 'b':[3,7]}
pd.DataFrame(d)
# Out:
#    a  b
# 0  2  3
# 1  6  7
